# %% [markdown]
# # GG4257 - Urban Analytics
# ---
# ## Assignment 1
# ---
#
# ### Lab 1 Challenges
#
# - <a href="#Challenge-1:">Challenge 1</a>
# - <a href="#Challenge-2:">Challenge 2</a>
# - <a href="#Challenge-3:">Challenge 3</a>
# - <a href="#Challenge-4:">Challenge 4</a>
# - <a href="#Challenge-5:">Challenge 5</a>
# - <a href="#Challenge-6:">Challenge 6</a>
# - <a href="#Challenge-7:">Challenge 7</a>
# - <a href="#Challenge-8:">Challenge 8</a>
# - <a href="#Challenge-9:">Challenge 9</a>
# ---

# %%
import random
import numpy as np

# %% [markdown]
# ### Challenge 1:
#  Create a table with required columns and rows to represent the type of roads in the UK. The table should include headers and hiperlinks.

# %% [markdown]
# | Road types | Description |
# | ------ | --- |
# | A-roads | Major roads, either single or duel carriageway in both urban and rural areas, e.g., [the A1](https://en.wikipedia.org/wiki/A1_road_(Great_Britain)) |
# | B and C-roads | Minor roads, connecting small towns and villages, these make up 87% of the UK's total road network. |
# | Motorways | High-speed roads allowing movement between major towns and cities, e.g., [the M25](https://en.wikipedia.org/wiki/M25_motorway) circling London |

# %% [markdown]
# Used markdown syntax to create a table of different UK road types, with links to a couple of examples

# %% [markdown]
# ### Challenge 2:
#
# Create the code to calculate the average of three numbers and print the result. There is no need for functions.

# %%
num1 = float(input("Please enter the first number: "))
num2 = float(input("Please enter the second number: "))
num3 = float(input("Please enter the third number: "))

print("The mean average of these three figure is ",((num1+num2+num3)/3))

# %% [markdown]
# The first three lines of code in the above cell ask for the user to input 3 number, the including of 'float' rather than 'int' meaning that these numbers can be decimal rather than requiring an integer.
#
# The result is calculated and printed in the final line. The output is as follows:
#
# ![Screenshot 2024-02-17 at 14.03.10.png](attachment:964d4034-7c17-4f0d-8d0b-caaadb749f3b.png)

# %% [markdown]
# ### Challenge 3:
#
# Write a condition to check if a number is even.

# %%
num1 = int(input("Please enter a number: "))

if num1%2 == 0:
    print("Your number is even.")
else:
    print("Your number is odd.")

# %% [markdown]
# The first line of code asks for the user to input a number to test. Then an if statement uses the modulus function to work out of the number if even or odd. If the inputted number MOD 2 (% being the python symbol for MOD) is equal to 0, the number is even and a print statement is executed to reflect this. Otherwise, the code skips to 'else' and prints that the number is odd.
#
# Even number:
# ![Screenshot 2024-02-17 at 14.16.50.png](attachment:1810fc6f-e85e-4f38-8f55-6e4e45a75ca3.png)
#
# Odd number:
# ![Screenshot 2024-02-17 at 14.15.45.png](attachment:b587bfb3-7743-4a1d-8164-cb420b7d645d.png)

# %% [markdown]
# ### Challenge 5:
#
# Help me to write the python code, I can use to provide the grades based on the marks according to the following table:
#
# | Mark   | Grade |
# |--------|-------|
# | 81-100 | 20    |
# | 61-80  | 15    |
# | 41-60  | 10    |
# | 20-40  | 5     |

# %%
mark = int(input("Please enter the mark you received: "))

if mark > 20:
    if 20 <= mark <=40:
        print("You have achieved a 5.")
    elif 41 <= mark <= 60:
        print("You have achieved a 10. ")
    elif 61 <= mark <= 80:
        print("You have achieved a 15. ")
    else:
        print("You have achieved a 20. ")
else:
    print("Ungraded.")

# %% [markdown]
# The first line asks for the user to input their mark, storing it in a variable 'mark'. If the mark is below 20, the programme outputs that the work is ungraded. Otherwise, it runs through a series of if and elif statments until it finds the first grade, and outputs the corresponding message.
#
# ![Screenshot 2024-02-17 at 14.30.26.png](attachment:76c54364-714d-4d03-b876-30be9a77b65b.png)

# %% [markdown]
# ### Challenge 6:
#
# * Write and use a function to convert Fahrenheit to Celsius. Use the input parameter to let the user enter a number in Fahrenheit and then get the correspondant value in Celsius
# * Go to https://www.w3schools.com/python/exercise.asp?filename=exercise_functions1 and complete the 6 excersices. Functions are a very important part of Python so we will use extra time to practice that.

# %%
def tempConv (fahrenheit):
    result = ((fahrenheit-32)*5)/9
    return result

fahrenheit = float(input("Please enter the temperature in fahrenheit: "))
celsius = tempConv(fahrenheit)
print("The temperature in Celsius is ",round(celsius,1)," degrees.")
#also rounds the result to 1 decimal place

# %% [markdown]
# The first three lines define a function, carrying over the input given by the user in the fourth line, calculating what the temperature in celcius is, and returning the result, which is stored in a variable 'celcius'. The final line prints the output rounded to 1 decimal place.
#
# ![Screenshot 2024-02-17 at 14.35.30.png](attachment:e3a12ac8-38b1-4fb1-8ec9-5663df216ee6.png)

# %% [markdown]
# ### Challenge 7:
#
# Calculate the mean and standard deviation of elements in a NumPy array. The outcome should have something like ``print(f"Mean: {mean_value}, Standard Deviation: {std_deviation}")`

# %%
array = np.random.randint(1,10, size=(10))
print(array)

mean_value = np.mean(array)
std_deviation = np.std(array)

print(f"Mean: {mean_value}, Standard Deviation: {std_deviation}")

# %% [markdown]
# The first line of the above cell imports numpy into this page as we haven't yet used it. The next line created an numpy array with 10 random integers between 1 and 10.
# The mean and standard deviation are then calculated with numpy statistics routines, and are outputted in the final line in a string format.

# %% [markdown]
# ### Challenge 8:
# You have the following dataframes 'sales_data' and 'movie_ratings'

# %%
import pandas as pd

sales_data_dict = {
    'Date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04'],
    'Region': ['North', 'South', 'East', 'West'],
    'Product': ['A', 'B', 'A', 'C'],
    'Quantity': [15, 8, 12, 10],
    'Revenue': [1500, 1200, 1800, 900]
}

sales_data = pd.DataFrame(sales_data_dict)


movie_ratings_dict = {
    'Title': ['Movie1', 'Movie2', 'Movie3', 'Movie4'],
    'Genre': ['Action', 'Drama', 'Comedy', 'Thriller'],
    'Year': [2015, 2010, 2018, 2011],
    'Rating': [8.5, 7.8, 9.2, 8.0]
}

movie_ratings = pd.DataFrame(movie_ratings_dict)

print(sales_data)
print(movie_ratings)

# %% [markdown]
# 1. Display the first 5 rows of the DataFrame 'sales_data'

# %%
print(sales_data.head()) # only 4 rows in total so only prints these

# %% [markdown]
# 2. Use `loc` to filter and display rows where the "Quantity" is greater than 10 and the "Region" is "North".

# %%
sales_data.loc[(sales_data.Region == "North") & (sales_data.Quantity > 10)] # loc to filter by value

# %% [markdown]
# 3. Use `iloc` to display the values in the first row and the first three columns.

# %%
sales_data.iloc[0,0:3] #using iloc to return rows from specific indexes

# %% [markdown]
# 4. Calculate the total sales for each region and display the result.

# %%
sales_data["Pay"] = sales_data["Quantity"]*sales_data["Revenue"] #calculates and stores in new column
sales_data.Pay # displays new column

# %% [markdown]
# 5. Display the last 3 rows of the DataFrame 'movie_ratings'.

# %%
sales_data.iloc[0:3, 5] #returns last three rows (iloc due to calling by index

# %% [markdown]
# 6. Calculate and display the average rating for each genre.

# %%
movie_ratings['Rating'].mean() # returns the mean of this row

# %% [markdown]
# ### Challenge 9:
# Again this challenge has two parts, so I split them up as such here.
#
# 1. Recreate the explore map, but now using one of the columns to create a choropleth map Check this link to get more information https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.explore.html

# %%
import geopandas as gpd

road_accidents = gpd.read_file("Lab 1 Data/Road_Safety_Accidents.shp") #importing shapefile
road_accidents.explore(column="ACCIDENT_S") # explore displayed by Accident_S for choropleth

# %% [markdown]
# ![Screenshot 2024-02-18 at 12.45.02.png](attachment:da2cea81-1a1b-40bf-a5a6-defd366e8623.png)

# %% [markdown]
# 2. Get the histogram of the raster you plot in the exercise. Here you can get an example of how to do it: https://rasterio.readthedocs.io/en/latest/topics/plotting.html

# %%
import rasterio
from rasterio.plot import show_hist

raster = rasterio.open('Lab 1 Data/elev.tif') #importing the raster

#plotting the histogram
show_hist(raster, bins=100, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram of elevation")

# %% [markdown]
# ![image.png](attachment:05aa8857-2448-45f8-9f8e-d0a1183af73a.png)
